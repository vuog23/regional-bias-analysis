# %%
import os
os.chdir('..')

# %%
from src.evaluate.imagenet_eval import ImageNetEval
from src.utils.geode_imagenet_mapping import GEODE_TO_IMAGENET_IDX

# %%
GEODE_TEST_ROOT = r"D:\Project\DAP_paper\datasets\processed\GeoDE_split\test"
MODEL_CONFIGS = {
    "convnextv2_base": "convnextv2_base.fcmae_ft_in22k_in1k",
    "swinv2_base": "swinv2_base_window12to24_192to384.ms_in22k_ft_in1k",
    "deit3_base": "deit3_base_patch16_224.fb_in22k_ft_in1k",
    "dinov2_vitb14": "vit_base_patch14_dinov2.lvd142m",
}

# %%
convnextv2_evaluator = ImageNetEval(
    root_path=GEODE_TEST_ROOT,
    model_name=MODEL_CONFIGS["convnextv2_base"],
    target_to_imagenet_idx=GEODE_TO_IMAGENET_IDX,
    batch_size=64,
    region_index=2,
)

convnextv2_results = convnextv2_evaluator.evaluate()
convnextv2_evaluator.print_summary(convnextv2_results)
# Out:
# Device: cuda
# Loaded timm pretrained model
# Model: convnextv2_base.fcmae_ft_in22k_in1k
# Dataset classes: 40
# Mapped classes: 34
# Unmapped / skipped classes: 6
# Unmapped: ['hairbrush_comb', 'spices', 'stall', 'toothbrush', 'toothpaste_toothpowder', 'tree']
# 100%|██████████| 251/251 [02:29<00:00,  1.68it/s]
# ImageNet-pretrained evaluation
# Model: convnextv2_base.fcmae_ft_in22k_in1k
#
# Accuracy:           63.67%
# Evaluated images:   13517
# Skipped images:     2538
#
# Region bias summary
#
# Best region:                     Europe
# Worst region:                    WestAsia
# Region gap:                      4.37%
# Region std:                      1.83%
#
# Object-balanced best region:     Americas
# Object-balanced worst region:    WestAsia
# Object-balanced region gap:      4.94%
# Object-balanced region std:      1.81%

# %%
convnextv2_df = convnextv2_results["region_df"]

convnextv2_df["accuracy_percent"] = convnextv2_df["accuracy"] * 100
convnextv2_df["object_balanced_accuracy_percent"] = convnextv2_df["object_balanced_accuracy"] * 100

region_df = convnextv2_df.sort_values("region")

display(region_df)
# Out:
#           region     n  accuracy  object_balanced_accuracy  accuracy_percent  \
# 0         Africa  3113  0.620302                  0.625737         62.030196
# 1       Americas  1933  0.657527                  0.664745         65.752716
# 2       EastAsia  1975  0.633924                  0.634518         63.392405
# 3         Europe  2555  0.659100                  0.648403         65.909980
# 4  SouthEastAsia  2342  0.633646                  0.625144         63.364646
# 5       WestAsia  1599  0.615385                  0.615334         61.538462
#
#    object_balanced_accuracy_percent
# 0                         62.573671
# 1                         66.474488
# 2                         63.451759
# 3                         64.840307
# 4                         62.514410
# 5                         61.533383
